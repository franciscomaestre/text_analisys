# %%
# %matplotlib inline
# Out:
# /home/paco/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_multilabel_classification
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import LabelBinarizer
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import CCA
from sklearn.svm.classes import LinearSVC

# %% [markdown]
# ### Set initial path

# %%
import os, sys
print(os.getcwd())
os.chdir('./seologies-python')
os.getcwd()
#sys.path.insert(0, os.path.join(PROJECT_ROOT, "./seologies-python/"))
# Out:
# /opt/seologies-python/experiments/classifier
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-fa5d897cda25> in <module>()
#       1 import os, sys
#       2 print(os.getcwd())
# ----> 3 os.chdir('./seologies-python')
#       4 os.getcwd()
#       5 #sys.path.insert(0, os.path.join(PROJECT_ROOT, "./seologies-python/"))
#
# OSError: [Errno 2] No such file or directory: './seologies-python'

# %%
from time import time
from multiprocessing import cpu_count
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report
import cPickle

from core.config import settings
from experiments.classifier.topics.extractor import getTopicList, getData

# %% [markdown]
# ### Get topic data

# %% [markdown]
# Alimentación, bebida y tabaco > Alimentos
# Alimentación, bebida y tabaco > Alimentos > Carne, marisco y huevos
# Alimentación, bebida y tabaco > Alimentos > Carne, marisco y huevos > Carne
# Arte y ocio > Fiestas y celebraciones
# Arte y ocio > Fiestas y celebraciones > Productos para fiestas
# Arte y ocio > Fiestas y celebraciones > Productos para fiestas > Artículos para fiestas
# Casa y jardín > Jardín
# Casa y jardín > Jardín > Jardinería
# Casa y jardín > Jardín > Jardinería > Accesorios de jardinería
# Casa y jardín > Jardín > Jardinería > Accesorios de jardinería > Mesas de jardinería
#
# ['Alimentos Alimentación, bebida y tabaco', 'Carne, marisco y huevos Alimentación, bebida y tabaco', 'Carne Alimentación, bebida y tabaco']
#
# ['Fiestas y celebraciones Arte y ocio', 'Productos para fiestas Arte y ocio', 'Artículos para fiestas Arte y ocio' ]
#
# ['Jardín Casa y jardín', 'Jardinería Casa y jardín', 'Accesorios de jardinería Casa y jardín', 'Mesas de jardinería Casa y jardín']

# %%
language=u'es'
country=u'ES'

initLevel = 1
levelHeader = 'Level %s'%initLevel
topicList = getTopicList('experiments/classifier/data/products/taxonomy.es-ES.txt', initLevel=initLevel)

# %%
topics = pd.DataFrame(topicList.items())
topics.columns = [levelHeader, 'queries']
topics['num_q'] = topics.apply(lambda x: len(x['queries']), axis=1)

# %%
topics.describe()
# Out:
#             num_q
# count  127.000000
# mean    78.732283
# std    156.954470
# min      4.000000
# 25%     10.000000
# 50%     19.000000
# 75%     62.000000
# max    916.000000

# %%
topics
# Out:
#                                                Level 1  \
# 0                                  Productos del hogar
# 1                      Mantenimiento del orden público
# 2                                          Estanterías
# 3                                  Carritos de oficina
# 4                           Materiales de construcción
# 5                        Bolsos, billeteras y estuches
# 6                           Artículos para videojuegos
# 7                                     Cocina y comedor
# 8                                Fitness y musculación
# 9                         Accesorios para herramientas
# 10                             Protección para el bebé
# 11                                    Vallas de jardín
# 12                                   Prendas de vestir
# 13                               Accesorios para sofás
# 14                      Accesorios para presentaciones
# 15                                Piercings y tatuajes
# 16                                          Decoración
# 17                                          Fotografía
# 18                                        Rompecabezas
# 19               Estructuras para juegos al aire libre
# 20                                             Cámaras
# 21          Accesorios para hornos de leña y chimeneas
# 22                Equipo de protección para el trabajo
# 23                                        Construcción
# 24                      Accesorios ópticos y de cámara
# 25                                  Juegos de interior
# 26                              Mobiliario de exterior
# 27                             Accesorios de bricolaje
# 28                                        Restauración
# 29                                      Salud del bebé
# ..                                                 ...
# 97                                               Armas
# 98   Protección contra inundaciones, gases e incendios
# 99                                        Complementos
# 100                                              Audio
# 101                               Artículos religiosos
# 102                                 Camas y accesorios
# 103                Accesorios para bolsos y billeteras
# 104              Accesorios para mobiliario de oficina
# 105                          Armarios y almacenamiento
# 106                                       Comunicación
# 107                            Productos para mascotas
# 108                               Equipos para oficina
# 109                                       Herramientas
# 110                                Transporte de bebés
# 111                             Disfraces y accesorios
# 112                             Publicidad y márketing
# 113                 Piezas y accesorios para vehículos
# 114                                        Ordenadores
# 115                                             Jardín
# 116                  Juguetes y actividades para bebés
# 117                                        Iluminación
# 118                              Manuales de productos
# 119                                          Alimentos
# 120                                  Electrodomésticos
# 121                                Productos generales
# 122                          Hobbies y artes creativas
# 123                          Accesorios de iluminación
# 124                         Pañales y cuidado del bebé
# 125                              Ciencia y laboratorio
# 126                                      Baño de bebés
#
#                                                queries  num_q
# 0    [Organizadores con cargadores Productos del ho...    246
# 1    [Mantenimiento del orden público Sujeciones me...      4
# 2    [Estanterías Estantes y estanterías, Estanterí...      4
# 3    [Carritos multiusos Carritos de oficina, Carri...     10
# 4    [Tapajuntas de techo Materiales de construcció...     78
# 5    [Colgadores para pases e insignias Bolsos, bil...      8
# 6    [Muebles de videojuegos de arcade Artículos pa...     12
# 7    [Filtros de agua para cafeteras, Cuencos Cocin...    778
# 8    [Estantes de almacenamiento de pesas libres Fi...    108
# 9    [Accesorios para detectores de gas Accesorios ...    130
# 10   [Barandillas de seguridad Protección para el b...     12
# 11   [Paneles de vallas Vallas de jardín, Barreras ...     16
# 12   [Chalecos de caza y pesca, Uniformes de servic...    234
# 13   [Soportes para sillas y sofás, Soportes para s...      4
# 14   [Accesorios para presentaciones Transparencias...     32
# 15   [Instrumentos para piercings Agujas para pierc...     14
# 16   [Atrapasoles Decoración, Portainciensos Decora...    262
# 17   [Herramientas de enfoque Fotografía, Equipo de...     62
# 18   [Puzles de madera y con agarrador, Accesorios ...      8
# 19   [Estructuras para juegos al aire libre Casitas...     19
# 20   [Cámaras Boroscopios, Cámaras Cámaras de fotos...     16
# 21   [Accesorios para hornos de leña y chimeneas, A...     12
# 22   [Equipo de protección para el trabajo Trajes c...     17
# 23   [Agrimensura Construcción, Conos y balizas de ...      4
# 24   [Accesorios para trípodes y monopiés, Accesori...     54
# 25   [Ping pong Juegos de interior, Billar Bolas de...    102
# 26   [Sofás modulares de exterior Mobiliario de ext...     22
# 27   [Puntas para anclaje en el suelo Accesorios de...    114
# 28   [Restauración Cajas para pasteles, Vajilla des...     44
# 29   [Kits de salud y aseo del bebé, Salud del bebé...     10
# ..                                                 ...    ...
# 97   [Accesorios y cuidado de armas de fuego Correa...     54
# 98   [Protección contra inundaciones, gases e incen...      9
# 99   [Complementos Pañuelos de bolsillo, Cinturones...    110
# 100  [Sistemas de karaokes Audio, Juegos de accesor...    128
# 101  [Rosarios Artículos religiosos, Artículos reli...     10
# 102  [Cabeceros y pies de cama Camas y accesorios, ...     10
# 103  [Accesorios para bolsos y billeteras Fundas pa...      5
# 104  [Accesorios y productos para escritorios, Acce...      4
# 105  [Armarios y almacenamiento Aparadores del come...     36
# 106  [Accesorios para móviles Fundas para móviles, ...     54
# 107  [Jaulas y habitáculos para animales pequeños P...    236
# 108  [Equipos para oficina Calculadoras, Plastifica...     20
# 109  [Cortadoras de troncos Herramientas, Sierras S...    346
# 110  [Transporte de bebés Sillas de coche, Transpor...      6
# 111  [Disfraces y accesorios Accesorios para disfra...     24
# 112  [Publicidad y márketing Folletos, Folletos Pub...      6
# 113  [Mantenimiento, cuidado y decoración de vehícu...    213
# 114  [Mesas táctiles Ordenadores, Servidores inform...     26
# 115  [Complementos para arados y multicultores Jard...    288
# 116  [Juguetes y actividades para bebés, Juguetes y...     14
# 117  [Bombillas con diodos led Iluminación, Luces n...     48
# 118  [Manuales de aparatos de cocina Manuales de pr...     18
# 119  [Entremeses y aperitivos Alimentos, Azúcar y e...    608
# 120  [Prensas de vapor Electrodomésticos, Secadoras...     70
# 121  [Etiquetas y etiquetas adhesivas Cinta para et...     64
# 122  [Piezas para clarinete Barriletes para clarine...    862
# 123  [Temporizadores para luz Accesorios de ilumina...     10
# 124  [Dispensadores y calentadores de toallitas par...     13
# 125  [Equipo de laboratorio Microtomos, Equipo de l...     66
# 126  [Viseras de ducha Baño de bebés, Baño de bebés...      4
#
# [127 rows x 3 columns]

# %%
#fig = plt.figure()
#fig, axes = fig.add_subplot(nrows=1, ncols=2)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
topics.plot(ax=axes[0], x=levelHeader, y='num_q', kind='hist', bins=20, legend=True, sharex=False, sharey=False)
topics.plot(ax=axes[1], x=levelHeader, y='num_q', kind='bar', legend=True, sharex=False, sharey=False)
#topics.plot(x='Level 0', y='num_q', kind='hist', legend=True)
#topics.plot(x='Level 0', y='num_q', kind='bar', legend=True)

# %% [markdown]
# ### Get Text Data

# %%
from core.seo.data.seo_document_downloader import SeoDocumentDownloader
from core.utils.translator import TranslatorFactory
from core.seo.data.seo_library import SeoLibrary
import random
from core.cache.file_storage_factory import FileStorageFactory
from core.config import settings
from core.search_engines.google import getGoogleHost
from core.search_engines.google.google_scraper import GoogleScraper
from core.utils.remain_timer import RemainTimer
from experiments.classifier.models.trainer_data import TrainerData
TRAINER_DOWNLOAD_LIMIT = 35

# %%
print len(topics)
print(topics.iloc[1])
print(topics.iloc[7])
print(topics.iloc[20])
search_topics = {topics.iloc[1][levelHeader]: topics.iloc[1]['queries']} 
search_topics.update( {topics.iloc[7][levelHeader]: topics.iloc[7]['queries']} )
search_topics.update( {topics.iloc[20][levelHeader]: topics.iloc[20]['queries']} )
num_queries = sum(len(t) for t in search_topics.values())
# Out:
# 127
# Level 1                      Mantenimiento del orden público
# queries    [Mantenimiento del orden público Sujeciones me...
# num_q                                                      4
# Name: 1, dtype: object
# Level 1                                     Cocina y comedor
# queries    [Filtros de agua para cafeteras, Cuencos Cocin...
# num_q                                                    778
# Name: 7, dtype: object
# Level 1                                              Cámaras
# queries    [Cámaras Boroscopios, Cámaras Cámaras de fotos...
# num_q                                                     16
# Name: 20, dtype: object

# %% [markdown]
# ### Download Google

# %%
def _getGoogleLinks(query, language, country, downloadLimit):
    try:
        googleSearch = GoogleScraper(query,
                               language=language,
                               country=country,
                               googleHost=getGoogleHost(country),
                               max_results=downloadLimit)
        print u'Links encontrados... %s' % len(googleSearch.search(True))
    except Exception as ex:
        print(ex)
        
def _getSeoDocuments(query, language, country, downloadLimit):
    try:
        return  SeoDocumentDownloader(query=query,
                                       language=language,
                                       country=country,
                                       downloadLimit=downloadLimit,
                                       sameOrigin=False
                                       ).getSeoDocuments() 
    except Exception as ex:
        print(ex)
        return []

# %%
# Download Google

translator = TranslatorFactory.getTranslator()
for topic, topicQueries in search_topics.items():
    num_download = min(len(topicQuerys), 20)
    
    print("%s %s"%(topic, num_download))
    for topicQuery in topicQueries:
        print(topicQuery)
        _getGoogleLinks(translator.trans(topic + u' ' + topicQuery), language, country, TRAINER_DOWNLOAD_LIMIT)      

print (u'GOOGLE TERMINADO -- PASAMOS A LOS DOCUMENTOS')
# Out:
# Mantenimiento del orden público 4
# Mantenimiento del orden público Sujeciones mecánicas
# Links encontrados... 35
# Detectores de metal Mantenimiento del orden público
# Links encontrados... 35
# Sujeciones mecánicas Mantenimiento del orden público
# Links encontrados... 35
# Mantenimiento del orden público Detectores de metal
# Links encontrados... 35
# Cocina y comedor 4
# Filtros de agua para cafeteras
# Links encontrados... 35
# Cuencos Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Fuentes para servir
# Links encontrados... 35
# Rodillos de cocina Cocina y comedor
# Links encontrados... 35
# Cucharas Cocina y comedor
# Links encontrados... 35
# Recipientes para arroz Cocina y comedor
# Links encontrados... 35
# Cuencos de heladeras para frigorífico Cocina y comedor
# Links encontrados... 35
# Rejillas para barbacoas Cocina y comedor
# Links encontrados... 35
# Juegos de cristalería Cocina y comedor
# Links encontrados... 35
# Accesorios para termómetros de cocina
# Links encontrados... 35
# Envoltorios de comida Papel de cera
# Links encontrados... 35
# Palilleros y dispensadores de palillos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Raspadores de cocina
# Links encontrados... 35
# Cepillos de woks Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Neveras para vino
# Links encontrados... 35
# Soperas Cocina y comedor
# Links encontrados... 35
# Ollas de hierro Cocina y comedor
# Links encontrados... 35
# Accesorios para el almacenamiento de comida Cocina y comedor
# Links encontrados... 35
# Cantimploras Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Trituradores
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para fogones portátiles
# Links encontrados... 35
# Hornillas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Cacillos
# Links encontrados... 35
# Utensilios de servir Soperas
# Links encontrados... 35
# Electrodomésticos de cocina Yogurteras
# Links encontrados... 35
# Frascos Cocina y comedor
# Links encontrados... 35
# Tapaderas para sartenes y ollas Cocina y comedor
# Links encontrados... 35
# Moldes para quiche y tarta Cocina y comedor
# Links encontrados... 35
# Envoltorios de comida Papel de aluminio
# Links encontrados... 35
# Pesos y pinzas para manteles Cocina y comedor
# Links encontrados... 35
# Dispensadores de comida Cocina y comedor
# Links encontrados... 35
# Utensilios para bares Tapones para botellas
# Links encontrados... 35
# Juegos de café y té
# Links encontrados... 35
# Herramientas y utensilios de cocina Cronómetros de cocina
# Links encontrados... 35
# Cocteleras y accesorios Cocteleras
# Links encontrados... 35
# Cuencos de heladeras para frigorífico
# Links encontrados... 35
# Etiquetas para alimentos y bebidas Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios para hornear
# Links encontrados... 35
# Copas Cocina y comedor
# Links encontrados... 35
# Dispensadores de condimentos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Tenazas para alimentos
# Links encontrados... 35
# Herramientas y utensilios de cocina Ablandadores de carne
# Links encontrados... 35
# Pinzas de cocina Cocina y comedor
# Links encontrados... 35
# Hornos Cocina y comedor
# Links encontrados... 35
# Accesorios de sartenes para gofres
# Links encontrados... 35
# Especieros Cocina y comedor
# Links encontrados... 35
# Carros para barbacoas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Sartenes para freír
# Links encontrados... 34
# Utensilios de servir Platos para mantequilla
# Links encontrados... 35
# Herramientas y utensilios de cocina Cuchillos de cocina
# Links encontrados... 35
# Raspadores de cocina Rasquetas
# Links encontrados... 35
# Herramientas y utensilios de cocina Bandejas cubiteras
# Links encontrados... 35
# Apartadores y guantes para horno Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Jarras y decantadores
# Links encontrados... 35
# Tapas para tuppers Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Cucharas para bolas
# Links encontrados... 35
# Cafeteras con filtro Cocina y comedor
# Links encontrados... 35
# Freidoras Cocina y comedor
# Links encontrados... 35
# Arroceras Cocina y comedor
# Links encontrados... 35
# Ollas de vapor para alimentos Ollas de vapor
# Links encontrados... 35
# Electrodomésticos de cocina Heladeras
# Links encontrados... 35
# Tapones para botellas Cocina y comedor
# Links encontrados... 35
# Salseras Cocina y comedor
# Links encontrados... 35
# Accesorios para rodillos de cocina Cocina y comedor
# Links encontrados... 35
# Azucareros y lecheras Cocina y comedor
# Links encontrados... 35
# Neveras Cocina y comedor
# Links encontrados... 35
# Hornos tostadores Cocina y comedor
# Links encontrados... 35
# Máquinas de donuts Cocina y comedor
# Links encontrados... 35
# Aislantes térmicos para bebidas Cocina y comedor
# Links encontrados... 35
# Bolsas y contenedores para el almuerzo
# Links encontrados... 35
# Máquinas de algodón dulce Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Trituradores de basura
# Links encontrados... 35
# Cucharas para bolas Cucharas de helados
# Links encontrados... 35
# Herramientas y utensilios de cocina Tablas de cortar
# Links encontrados... 35
# Granizadoras y picadoras de hielo Cocina y comedor
# Links encontrados... 35
# Utensilios para bares Oxigenadores de vino
# Links encontrados... 35
# Láminas para deshidratadores de alimentos
# Links encontrados... 35
# Cascanueces Cascanueces decorativos
# Links encontrados... 35
# Herramientas y utensilios de cocina Delantales
# Links encontrados... 35
# Bandejas de cubiertos y utensilios
# Links encontrados... 35
# Recipiente para comida Bolsas de comida
# Links encontrados... 35
# Utensilios para hornear Cocina y comedor
# Links encontrados... 35
# Palas para hielo Cocina y comedor
# Links encontrados... 35
# Accesorios para cocinar Cocina y comedor
# Links encontrados... 35
# Woks Cocina y comedor
# Links encontrados... 35
# Máquinas de hielo Cocina y comedor
# Links encontrados... 35
# Bandejas para tartas Cocina y comedor
# Links encontrados... 35
# Abrelatas Cocina y comedor
# Links encontrados... 35
# Vitrinas calientes Cocina y comedor
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para barbacoas
# Links encontrados... 35
# Ollas térmicas Cocina y comedor
# Links encontrados... 35
# Sartenes para crepes Cocina y comedor
# Links encontrados... 35
# Accesorios de envasado al vacío Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Parrillas de enfriamiento
# Links encontrados... 35
# Apartadores y guantes para horno
# Links encontrados... 35
# Electrodomésticos de cocina Lavavajillas
# Links encontrados... 35
# Cuchillos eléctricos Cocina y comedor
# Links encontrados... 35
# Batidores de varillas Cocina y comedor
# Links encontrados... 35
# Lavavajillas Cocina y comedor
# Links encontrados... 35
# Esteras antideslizantes para fregaderos Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios para bebidas
# Links encontrados... 35
# Ollas de vapor para alimentos
# Links encontrados... 35
# Accesorios de sartenes para gofres Cocina y comedor
# Links encontrados... 35
# Asadores y hornos para asar
# Links encontrados... 35
# Tostadores y parrillas Máquinas de donuts
# Links encontrados... 35
# Palas para palomitas y patatas fritas
# Links encontrados... 35
# Vasos Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Aislantes térmicos para bebidas
# Links encontrados... 35
# Electrodomésticos de cocina Calentadores de comida
# Links encontrados... 35
# Accesorios para refrigeradores de agua Cocina y comedor
# Links encontrados... 35
# Soporte para ollas de fondue Cocina y comedor
# Links encontrados... 35
# Accesorios para woks Soportes para woks
# Links encontrados... 35
# Electrodomésticos de cocina Ahumadores de comida
# Links encontrados... 35
# Herramientas y utensilios de cocina Cuencos para mezclar
# Links encontrados... 35
# Accesorios para la eliminación de basura
# Links encontrados... 35
# Soporte para ollas de fondue
# Links encontrados... 35
# Electrodomésticos de cocina Hornillas
# Links encontrados... 35
# Termómetros de cocina Cocina y comedor
# Links encontrados... 35
# Cestas de picnic Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios de cocina
# Links encontrados... 35
# Electrodomésticos de cocina Afiladores de cuchillos
# Links encontrados... 35
# Electrodomésticos de cocina Horno de pan
# Links encontrados... 35
# Cucharas para bolas Palas para hielo
# Links encontrados... 35
# Rasquetas Cocina y comedor
# Links encontrados... 35
# Recipiente para comida Tarros de miel
# Links encontrados... 35
# Tostadores y parrillas Gofreras
# Links encontrados... 35
# Cubos de piedra para whisky y palos enfriadores de vino
# Links encontrados... 35
# Utensilios de mesa Cristalería
# Links encontrados... 35
# Gofreras Cocina y comedor
# Links encontrados... 35
# Accesorios para cafeteras Cocina y comedor
# Links encontrados... 35
# Paneras Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Azucareros
# Links encontrados... 35
# Tostadores y parrillas Máquinas de pretzels
# Links encontrados... 35
# Recipiente para comida Tapas para tuppers
# Links encontrados... 35
# Raspadores de cocina Espátulas de goma
# Links encontrados... 35
# Cocteleras y accesorios Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Bolsas para transportar vino
# Links encontrados... 35
# Accesorios para utensilios de servir Tapas para soperas
# Links encontrados... 35
# Máquinas para hacer pizellas o ferratellas
# Links encontrados... 7
# Papel y silicona para hornear Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Molinillos para especias
# Links encontrados... 35
# Bandejas para hornear Cocina y comedor
# Links encontrados... 35
# Vinagreras Cocina y comedor
# Links encontrados... 35
# Cestas y rejillas para barbacoas Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Woks y sartenes eléctricas
# Links encontrados... 35
# Moldes para magdalenas Cocina y comedor
# Links encontrados... 35
# Máquinas para hacer leche de soja Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Hervidores eléctricos
# Links encontrados... 35
# Cocina y comedor Utensilios de mesa
# Links encontrados... 35
# Accesorios para sartenes y woks eléctricos Cocina y comedor
# Links encontrados... 35
# Woks y sartenes eléctricas Cocina y comedor
# Links encontrados... 35
# Accesorios para neveras de vinos
# Links encontrados... 35
# Accesorios para utensilios de servir Cocina y comedor
# Links encontrados... 35
# Moldes para pan Cocina y comedor
# Links encontrados... 35
# Cristalería Cocina y comedor
# Links encontrados... 35
# Filtros de café Cocina y comedor
# Links encontrados... 35
# Envoltorios de comida Film plástico
# Links encontrados... 35
# Electrodomésticos de cocina Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Cantimploras
# Links encontrados... 35
# Encimeras y organizadores de bebidas Cocina y comedor
# Links encontrados... 35
# Accesorios para juegos de fondue Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Calentadores de bebidas
# Links encontrados... 35
# Bandejas para grill Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios para cocinar y para hornear
# Links encontrados... 35
# Moldes de cocina Cocina y comedor
# Links encontrados... 35
# Escurreplatos Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Paelleras
# Links encontrados... 35
# Espumaderas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Planchas
# Links encontrados... 35
# Exprimidores Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Pistolas para cecinas
# Links encontrados... 35
# Cascanueces Cocina y comedor
# Links encontrados... 35
# Accesorios para juegos de fondue
# Links encontrados... 35
# Moldes para gelatina Cocina y comedor
# Links encontrados... 35
# Cubiertos Juegos de cubertería
# Links encontrados... 35
# Objetos para llevar comida y bebida Frascos
# Links encontrados... 35
# Anillos niveladores para rodillos de cocina
# Links encontrados... 35
# Máquinas para leche de soja
# Links encontrados... 35
# Herramientas y utensilios de cocina Accesorios para cortapizzas
# Links encontrados... 35
# Cuchillos de mesa Cocina y comedor
# Links encontrados... 35
# Asadores y hornos para asar Cocina y comedor
# Links encontrados... 35
# Máquinas para hacer quesadillas y tortillas Cocina y comedor
# Links encontrados... 35
# Batidoras y licuadoras Cocina y comedor
# Links encontrados... 35
# Cafeteras de filtro Cocina y comedor
# Links encontrados... 35
# Tenedores trinchantes Cocina y comedor
# Links encontrados... 35
# Organizadores de cocina Especieros
# Links encontrados... 35
# Cubiertos Accesorios para palillos
# Links encontrados... 35
# Bolsas y contenedores para el almuerzo Cocina y comedor
# Links encontrados... 35
# Accesorios de horno de pan Cocina y comedor
# Links encontrados... 35
# Máquinas de expreso Cocina y comedor
# Links encontrados... 35
# Ralladores de comida Cocina y comedor
# Links encontrados... 35
# Máquinas para hacer quesadillas y tortillas
# Links encontrados... 35
# Cafeteras italianas tradicionales y eléctricas Cocina y comedor
# Links encontrados... 35
# Placas para calentar Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Pinzas de cocina
# Links encontrados... 35
# Molinillos de café Cocina y comedor
# Links encontrados... 35
# Accesorios para woks Cepillos de woks
# Links encontrados... 35
# Utensilios de mesa Utensilios de servir
# Links encontrados... 35
# Servilleteros y dispensadores de servilletas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Tajines y römertopf
# Links encontrados... 15
# Rejillas para fuentes de hornos
# Links encontrados... 35
# Sacacorchos Cocina y comedor
# Links encontrados... 35
# Cubiertos Tenedores
# Links encontrados... 35
# Herramientas y utensilios de cocina Espátulas de cocina
# Links encontrados... 35
# Máquinas para hacer pasta Cocina y comedor
# Links encontrados... 35
# Cafeteras Cafetera cona (por vacío)
# Links encontrados... 35
# Tenedores para fondue Cocina y comedor
# Links encontrados... 35
# Accesorios para cafeteras Molinillos de café
# Links encontrados... 35
# Herramientas y utensilios de cocina Cucharones
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para tostadoras
# Links encontrados... 35
# Electrodomésticos de cocina Filtros de agua
# Links encontrados... 35
# Cubetas para mesas de vapor
# Links encontrados... 35
# Cucharas cortamelón Cocina y comedor
# Links encontrados... 12
# Accesorios para utensilios de servir
# Links encontrados... 35
# Cacerolas Cocina y comedor
# Links encontrados... 35
# Accesorios y piezas de lavavajillas Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Cuchillos eléctricos
# Links encontrados... 35
# Electrodomésticos de cocina Cocinas de camping
# Links encontrados... 35
# Cucharas para bolas Cucharas cortamelón
# Links encontrados... 12
# Accesorios para aparatos de cocina Accesorios para yogurteras
# Links encontrados... 35
# Lámparas para calentar comida Cocina y comedor
# Links encontrados... 35
# Tarros de miel Cocina y comedor
# Links encontrados... 35
# Máquinas de granizados Cocina y comedor
# Links encontrados... 35
# Máquinas de hacer espuma de leche Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Freidoras
# Links encontrados... 35
# Juegos de utensilios para hornear Cocina y comedor
# Links encontrados... 35
# Bolsas de comida Cocina y comedor
# Links encontrados... 35
# Ollas de vapor para alimentos Hornos de agua
# Links encontrados... 35
# Herramientas y utensilios de cocina Coladores y filtros
# Links encontrados... 35
# Accesorios de horno de pan
# Links encontrados... 35
# Amasadores Cocina y comedor
# Links encontrados... 35
# Prensas para barbacoa Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Cortadoras de cocina
# Links encontrados... 35
# Platos para mantequilla Cocina y comedor
# Links encontrados... 35
# Cristalería Vasos
# Links encontrados... 35
# Accesorios para el almacenamiento de comida
# Links encontrados... 35
# Moldes para quiche y tarta
# Links encontrados... 35
# Productos para la decoración de pasteles Cocina y comedor
# Links encontrados... 35
# Recipiente para comida Envoltorios de comida
# Links encontrados... 35
# Herramientas y utensilios de cocina Pasapurés
# Links encontrados... 35
# Contenedores para utensilios de cocina
# Links encontrados... 35
# Electrodomésticos de cocina Hornos
# Links encontrados... 35
# Máquinas para hacer mochi Cocina y comedor
# Links encontrados... 35
# Cubos de caramelos Cocina y comedor
# Links encontrados... 35
# Accesorios para heladeras Cocina y comedor
# Links encontrados... 35
# Pinzas para mariscos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Moldes de cocina
# Links encontrados... 35
# Palillos Cocina y comedor
# Links encontrados... 35
# Accesorios para barbacoas Rejillas para barbacoas
# Links encontrados... 35
# Estanterías para cristalería Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Hornos microondas
# Links encontrados... 35
# Accesorios para granizadoras y picadoras de hielo
# Links encontrados... 35
# Teteras eléctricas Cocina y comedor
# Links encontrados... 35
# Cesta para filtros del café
# Links encontrados... 35
# Herramientas y utensilios de cocina Tamices de harina
# Links encontrados... 35
# Herramientas y utensilios de cocina Coladores de té
# Links encontrados... 35
# Ahumadores de comida Cocina y comedor
# Links encontrados... 35
# Accesorios para mesas de vapor
# Links encontrados... 35
# Utensilios para hornear Moldes para tartas
# Links encontrados... 35
# Accesorios para ollas a presión
# Links encontrados... 35
# Batería de cocina Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Ralladores de comida
# Links encontrados... 34
# Utensilios para bares Tapones
# Links encontrados... 35
# Juegos de café y té Cocina y comedor
# Links encontrados... 35
# Ablandadores de carne Cocina y comedor
# Links encontrados... 35
# Pinchos y brochetas para comida Cocina y comedor
# Links encontrados... 35
# Accesorios para cocinar Accesorios para woks
# Links encontrados... 35
# Film plástico Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Bolsas aislantes
# Links encontrados... 35
# Accesorios para triturador de comida Cocina y comedor
# Links encontrados... 35
# Rejillas para fuentes de hornos Cocina y comedor
# Links encontrados... 35
# Cacerolas para baño María Cocina y comedor
# Links encontrados... 35
# Dispensadores de bebidas Cocina y comedor
# Links encontrados... 35
# Cuencos para mezclar Cocina y comedor
# Links encontrados... 35
# Utensilios para bares Refrigeradores de bebidas
# Links encontrados... 35
# Utensilios para cocinar Cocina y comedor
# Links encontrados... 35
# Platos Cocina y comedor
# Links encontrados... 35
# Aislantes térmicos para latas y botellas
# Links encontrados... 35
# Adornos para copas de vino Cocina y comedor
# Links encontrados... 35
# Accesorios para hornear Pesos para hornear
# Links encontrados... 35
# Utensilios para hornear Bandejas para hornear
# Links encontrados... 35
# Herramientas y utensilios de cocina Peladores y descorazonadores
# Links encontrados... 35
# Mangos para sartenes y ollas
# Links encontrados... 35
# Jarras para espumar Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Soportes para tarta
# Links encontrados... 35
# Papel y silicona para hornear
# Links encontrados... 35
# Embudos Cocina y comedor
# Links encontrados... 35
# Fuentes de absenta Cocina y comedor
# Links encontrados... 35
# Organizadores de armarios de cocina
# Links encontrados... 35
# Pesos para hornear Cocina y comedor
# Links encontrados... 35
# Utensilios para bares Cocteleras y accesorios
# Links encontrados... 35
# Accesorios para utensilios de servir Soportes para poncheras
# Links encontrados... 35
# Vajilla Cuencos
# Links encontrados... 35
# Organizadores de cocina Soportes para sartenes
# Links encontrados... 35
# Coladores y filtros Cocina y comedor
# Links encontrados... 35
# Maza de mortero Cocina y comedor
# Links encontrados... 35
# Accesorios para congeladores Cocina y comedor
# Links encontrados... 35
# Gusanillos para colar cócteles Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Moldes para gelatina
# Links encontrados... 35
# Utensilios para cocinar y para hornear Utensilios para cocinar
# Links encontrados... 35
# Abridores Cocina y comedor
# Links encontrados... 35
# Bandejas de cubiertos y utensilios Cocina y comedor
# Links encontrados... 35
# Cocina y comedor Recipiente para comida
# Links encontrados... 35
# Trituradores de basura Cocina y comedor
# Links encontrados... 35
# Accesorios para barbacoas Tablas para barbacoas
# Links encontrados... 35
# Accesorios para placas de cocción, hornos y cocinas de gas
# Links encontrados... 35
# Moldes para pizza Cocina y comedor
# Links encontrados... 35
# Accesorios para sartenes y woks eléctricos
# Links encontrados... 35
# Delantales Cocina y comedor
# Links encontrados... 35
# Utensilios de mesa Apartadores
# Links encontrados... 35
# Accesorios para molinillo de café
# Links encontrados... 35
# Cucharones Cocina y comedor
# Links encontrados... 35
# Bandejas cubiteras Cocina y comedor
# Links encontrados... 35
# Cocedores de huevos Cocina y comedor
# Links encontrados... 34
# Vasijas para conservas y fermentación Cocina y comedor
# Links encontrados... 35
# Escurridores de ensalada Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios para bebidas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar y para hornear
# Links encontrados... 35
# Piezas de repuesto para cafeteras y máquinas de café espresso Cocina y comedor
# Links encontrados... 35
# Azucareros Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Acanaladores
# Links encontrados... 35
# Accesorios para máquina de algodón dulce
# Links encontrados... 35
# Ollas de vapor para alimentos Cocedores de huevos
# Links encontrados... 35
# Acanaladores Cocina y comedor
# Links encontrados... 35
# Raspadores de cocina Cocina y comedor
# Links encontrados... 35
# Planchas y parrillas eléctricas Cocina y comedor
# Links encontrados... 35
# Placas de cocina Cocina y comedor
# Links encontrados... 35
# Recipiente para comida Paneras
# Links encontrados... 35
# Electrodomésticos de cocina Placas de cocina
# Links encontrados... 35
# Electrodomésticos de cocina Congeladores
# Links encontrados... 35
# Tablas de cortar Cocina y comedor
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para exprimidores
# Links encontrados... 35
# Escalfadores Cocina y comedor
# Links encontrados... 35
# Vasos y jarras de cerveza
# Links encontrados... 35
# Cortadoras de cocina Cocina y comedor
# Links encontrados... 35
# Filtros de agua Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Cestas de picnic
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas para hacer pasta
# Links encontrados... 35
# Utensilios de servir Azucareros y lecheras
# Links encontrados... 35
# Accesorios para termómetros de cocina Cocina y comedor
# Links encontrados... 35
# Papel de aluminio Cocina y comedor
# Links encontrados... 35
# Copas para huevos Cocina y comedor
# Links encontrados... 35
# Soportes para botellas de vino
# Links encontrados... 35
# Tenedores Cocina y comedor
# Links encontrados... 35
# Cafeteras Cafeteras de filtro
# Links encontrados... 35
# WARNING:urllib3.connectionpool:Retrying (Retry(total=None, connect=2, read=2, redirect=2)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000116BE1D0>: Failed to establish a new connection: [Errno 10061] No connection could be made because the target machine actively refused it',))': http://google.es/search?safe=off&q=Cocina+y+comedor+Maquinas+para+hacer+leche+de+soja&start=0&num=100&lr=lang_es&hl=es&gl=ES
# WARNING:urllib3.connectionpool:Retrying (Retry(total=None, connect=2, read=2, redirect=2)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000011B8D390>: Failed to establish a new connection: [Errno 10061] No connection could be made because the target machine actively refused it',))': http://google.es/search?safe=off&q=Cocina+y+comedor+Maquinas+para+hacer+leche+de+soja&start=0&num=100&lr=lang_es&hl=es&gl=ES
# Máquinas para hacer leche de soja
# Links encontrados... 32
# Hervidores de agua Cocina y comedor
# Links encontrados... 35
# Tostadores Cocina y comedor
# Links encontrados... 35
# Máquinas para hacer magdalenas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Batería de cocina
# Links encontrados... 35
# Bandejas para hornear galletas Cocina y comedor
# Links encontrados... 35
# Espátulas de goma Cocina y comedor
# Links encontrados... 35
# Máquinas para leche de soja Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Tijeras de cocina
# Links encontrados... 35
# Herramientas y utensilios de cocina Vinagreras
# Links encontrados... 35
# Electrodomésticos de cocina Exprimidores
# Links encontrados... 35
# Envoltorios de comida Cocina y comedor
# Links encontrados... 35
# Cristalería Vasos de chupito
# Links encontrados... 35
# Accesorios para woks Cocina y comedor
# Links encontrados... 35
# Accesorios para granizadoras y picadoras de hielo Cocina y comedor
# Links encontrados... 35
# Aplastadores de latas Cocina y comedor
# Links encontrados... 35
# Tapones de botellas Cocina y comedor
# Links encontrados... 35
# Tamices de harina Cocina y comedor
# Links encontrados... 35
# Papel vegetal Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Cacerolas para baño María
# Links encontrados... 35
# Accesorios para fogones portátiles Cocina y comedor
# Links encontrados... 35
# Aparatos para hacer pizza Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Tenedores trinchantes
# Links encontrados... 35
# Recipiente para comida Botes de galletas
# Links encontrados... 35
# Dispensadores y soportes de pajitas
# Links encontrados... 35
# Objetos para llevar comida y bebida Termos dispensadores
# Links encontrados... 35
# Decantadores Cocina y comedor
# Links encontrados... 35
# Etiquetas para alimentos y bebidas
# Links encontrados... 35
# Utensilios para cocinar Ollas a presión
# Links encontrados... 35
# Herramientas y utensilios de cocina Cortapastas extensibles con ruedas
# Links encontrados... 35
# Herramientas y utensilios de cocina Pinceles de cocina
# Links encontrados... 35
# Cristalería Copas
# Links encontrados... 35
# Extractores Cocina y comedor
# Links encontrados... 35
# Trituradores Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas de granizados
# Links encontrados... 35
# Planchas Cocina y comedor
# Links encontrados... 35
# Oxigenadores de vino Cocina y comedor
# Links encontrados... 35
# Trituradores de desechos Cocina y comedor
# Links encontrados... 35
# Afiladores de cuchillos Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios de cocina Cocina y comedor
# Links encontrados... 35
# Tablas para barbacoas Cocina y comedor
# Links encontrados... 35
# Tapas de cubetas para mesas de vapor
# Links encontrados... 35
# Prensa para galletas Cocina y comedor
# Links encontrados... 35
# Hornos de agua Cocina y comedor
# Links encontrados... 35
# Calentadores de comida Recipientes para arroz
# Links encontrados... 35
# Tostadores y parrillas Máquinas para hacer magdalenas
# Links encontrados... 35
# Accesorios para cuchillos eléctricos Cocina y comedor
# Links encontrados... 35
# Cocina y comedor Utensilios para bares
# Links encontrados... 35
# Cacillos Cocina y comedor
# Links encontrados... 35
# Máquinas para derretir chocolate Cocina y comedor
# Links encontrados... 35
# Cocteleras y accesorios Abridores
# Links encontrados... 35
# Accesorios para batidoras y licuadoras
# Links encontrados... 35
# Organizadores de cocina Cocina y comedor
# Links encontrados... 35
# Hojas de recambio para cuchillos eléctricos
# Links encontrados... 35
# Cristalería Tazas
# Links encontrados... 35
# Herramientas y utensilios de cocina Organizadores de fregadero
# Links encontrados... 35
# Cucharas para bolas Cocina y comedor
# Links encontrados... 35
# Fundas para rodillos de cocina
# Links encontrados... 35
# Accesorios para cafeteras Jarras de café
# Links encontrados... 35
# Bolsas para transportar vino Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Cafeteras
# Links encontrados... 35
# Utensilios para cocinar Cacerolas
# Links encontrados... 35
# Barbacoas Cocina y comedor
# Links encontrados... 35
# Cronómetros de cocina Cocina y comedor
# Links encontrados... 35
# Accesorios de frigorífico Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Cocina y comedor
# Links encontrados... 35
# Organizadores de fregadero Cocina y comedor
# Links encontrados... 35
# Calentadores para jarras de café Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Amasadores
# Links encontrados... 35
# Botellas de agua Cocina y comedor
# Links encontrados... 35
# Parrillas de enfriamiento Cocina y comedor
# Links encontrados... 35
# Portacuchillos y bloques para cuchillos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Pipetas para salsas
# Links encontrados... 35
# Envoltorios de comida Papel vegetal
# Links encontrados... 35
# Electrodomésticos de cocina Planchas de gas
# Links encontrados... 35
# Accesorios para generadores de agua carbonatada
# Links encontrados... 35
# Utensilios para bares Fuentes de absenta
# Links encontrados... 35
# Ollas de vapor Cocina y comedor
# Links encontrados... 35
# Reposacucharas Cocina y comedor
# Links encontrados... 35
# Tostadores y parrillas Tostadores
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas para hacer mochi
# Links encontrados... 35
# Dispensadores y soportes de papel de cocina Cocina y comedor
# Links encontrados... 35
# Tostadores y parrillas Cocina y comedor
# Links encontrados... 35
# Sartenes para saltear Cocina y comedor
# Links encontrados... 35
# Soportes para posavasos Cocina y comedor
# Links encontrados... 35
# Absorbentes de oxígeno Cocina y comedor
# Links encontrados... 35
# Cafeteras de émbolo Cocina y comedor
# Links encontrados... 35
# Ollas de vapor para alimentos Ollas térmicas
# Links encontrados... 35
# Portafiltros Cocina y comedor
# Links encontrados... 35
# Accesorios para aparatos de cocina Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Paños de amasar
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para cafeteras
# Links encontrados... 35
# Vajilla Platos
# Links encontrados... 35
# Utensilios para bares Decantadores
# Links encontrados... 35
# Bolsas aislantes Cocina y comedor
# Links encontrados... 35
# Molinos y trituradoras de comida Cocina y comedor
# Links encontrados... 35
# Moldes y sellos para pasta
# Links encontrados... 35
# Accesorios para la eliminación de basura Cocina y comedor
# Links encontrados... 35
# Grifos y dispensadores de cerveza
# Links encontrados... 35
# Palas para palomitas y patatas fritas Cocina y comedor
# Links encontrados... 35
# Accesorios para refrigeradores de agua
# Links encontrados... 35
# Adornos para copas de vino
# Links encontrados... 35
# Tajines y römertopf Cocina y comedor
# Links encontrados... 21
# Accesorios para molinillo de café Cocina y comedor
# Links encontrados... 35
# Organizadores de latas Cocina y comedor
# Links encontrados... 35
# Pinzas para bolsas y ataduras de alambre
# Links encontrados... 35
# Tenazas para alimentos Cascanueces
# Links encontrados... 35
# Bolsas de cocción al vapor Cocina y comedor
# Links encontrados... 35
# Utensilios de mesa Saleros y pimenteros
# Links encontrados... 35
# Utensilios para bares Posavasos
# Links encontrados... 35
# Organizadores de cocina Recipientes para azucarillos
# Links encontrados... 35
# Accesorios para freidoras Cocina y comedor
# Links encontrados... 35
# Pipetas para salsas Cocina y comedor
# Links encontrados... 35
# Juegos de cubertería Cocina y comedor
# Links encontrados... 35
# Coladores de té Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Moldes de galletas
# Links encontrados... 35
# Herramientas y utensilios de cocina Dispensadores de comida
# Links encontrados... 35
# Utensilios para cocinar Ollas altas
# Links encontrados... 35
# Chimeneas de carbón Cocina y comedor
# Links encontrados... 35
# Accesorios para el almacenamiento de comida Dispensadores de film plástico
# Links encontrados... 35
# Herramientas y utensilios de cocina Morteros
# Links encontrados... 35
# Piezas de repuesto para cafeteras y máquinas de café espresso
# Links encontrados... 35
# Cuchillos de cocina Cocina y comedor
# Links encontrados... 35
# Accesorios para mesas de vapor Cocina y comedor
# Links encontrados... 35
# Moldes de galletas Cocina y comedor
# Links encontrados... 35
# Soportes para sartenes Cocina y comedor
# Links encontrados... 35
# Utensilios para bares Cortacápsulas
# Links encontrados... 35
# Herramientas y utensilios de cocina Cortadores de pizza
# Links encontrados... 35
# Herramientas y utensilios de cocina Prensa para galletas
# Links encontrados... 35
# Congeladores Cocina y comedor
# Links encontrados... 35
# Cubos de piedra para whisky y palos enfriadores de vino Cocina y comedor
# Links encontrados... 35
# Dispensadores y soportes de pajitas Cocina y comedor
# Links encontrados... 35
# Neveras para vino Cocina y comedor
# Links encontrados... 35
# Horno de pan Cocina y comedor
# Links encontrados... 35
# Accesorios para batidoras y licuadoras Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Bolsas para horno
# Links encontrados... 35
# Productos para la decoración de pasteles
# Links encontrados... 35
# Accesorios para aparatos de cocina
# Links encontrados... 35
# Utensilios para bares Cocina y comedor
# Links encontrados... 35
# Piedras para pizza Cocina y comedor
# Links encontrados... 35
# Yogurteras Cocina y comedor
# Links encontrados... 35
# Cafeteras Máquinas de expreso
# Links encontrados... 35
# Accesorios para utensilios de servir Soportes para soperas
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para microondas
# Links encontrados... 35
# Dispensadores y soportes de papel de cocina
# Links encontrados... 35
# Herramientas y utensilios de cocina Accesorios para cuchillos eléctricos
# Links encontrados... 35
# Cubetas para mesas de vapor Cocina y comedor
# Links encontrados... 35
# Papel de cera Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios para cocinar y para hornear Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Mezcladores de aliños
# Links encontrados... 35
# Herramientas y utensilios de cocina Batidores de varillas
# Links encontrados... 35
# Pasapurés Cocina y comedor
# Links encontrados... 35
# Espátulas de cocina Cocina y comedor
# Links encontrados... 35
# Ollas de vapor para alimentos Arroceras
# Links encontrados... 35
# Soplete para cocinar Cocina y comedor
# Links encontrados... 35
# Cocteleras Cocina y comedor
# Links encontrados... 35
# Utensilios para hornear Moldes para pizza
# Links encontrados... 35
# Accesorios para campana de cocina
# Links encontrados... 35
# Tostadores y parrillas Hornos tostadores
# Links encontrados... 35
# Botellas para refrigeradores de agua Cocina y comedor
# Links encontrados... 35
# Combustible en gel para cocinar Cocina y comedor
# Links encontrados... 35
# Accesorios para barbacoas Carros para barbacoas
# Links encontrados... 35
# Hojas de recambio para cuchillos eléctricos Cocina y comedor
# Links encontrados... 35
# Cocinas de camping Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Reposacucharas
# Links encontrados... 35
# Combustible en gel para cocinar
# Links encontrados... 35
# Ollas de vapor para alimentos Ollas de cocción lenta
# Links encontrados... 35
# Botellas para refrigeradores de agua
# Links encontrados... 35
# Cucharas de helados Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Envasados al vacío
# Links encontrados... 35
# Accesorios de molinillo para especias Cocina y comedor
# Links encontrados... 35
# Juegos para fondues Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Dispensadores enfriadores de agua
# Links encontrados... 35
# Cristalería Juegos de cristalería
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas de algodón dulce
# Links encontrados... 35
# Utensilios para hornear Moldes para magdalenas
# Links encontrados... 35
# Accesorios para barbacoas Cubiertas para barbacoas
# Links encontrados... 35
# Accesorios para máquinas de palomitas
# Links encontrados... 35
# Saleros y pimenteros Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Bandejas
# Links encontrados... 35
# Accesorios para cafeteras Portafiltros
# Links encontrados... 35
# Utensilios para bares Sacacorchos
# Links encontrados... 35
# Accesorios para máquinas de hielo Cocina y comedor
# Links encontrados... 35
# Accesorios de molinillo para especias
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios de frigorífico
# Links encontrados... 35
# Utensilios para cocinar Prensas para barbacoa
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para heladeras
# Links encontrados... 35
# Bandejas para deshidratadores de alimentos
# Links encontrados... 35
# Accesorios y piezas de lavavajillas
# Links encontrados... 35
# Utensilios para hornear Moldes para pan
# Links encontrados... 35
# Encimeras y organizadores de bebidas
# Links encontrados... 35
# Calentadores de bebidas Cocina y comedor
# Links encontrados... 35
# Piezas de repuesto para barbacoas exteriores
# Links encontrados... 35
# Utensilios para cocinar Ollas de hierro
# Links encontrados... 35
# Molinos y trituradoras de comida
# Links encontrados... 35
# Herramientas y utensilios de cocina Dispensadores de condimentos
# Links encontrados... 35
# Platos de café y té
# Links encontrados... 35
# Accesorios para exprimidores Cocina y comedor
# Links encontrados... 35
# Mezcladores de aliños Cocina y comedor
# Links encontrados... 35
# Pellets y virutas de madera para ahumar
# Links encontrados... 35
# Accesorios para hervidores de agua Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Palas para pasteles
# Links encontrados... 35
# Heladeras Cocina y comedor
# Links encontrados... 35
# Accesorios para hervidores de agua
# Links encontrados... 35
# Máquinas para hacer pizellas o ferratellas Cocina y comedor
# Links encontrados... 7
# Utensilios para cocinar y para hornear Utensilios para hornear
# Links encontrados... 35
# Utensilios para bares Soportes para posavasos
# Links encontrados... 35
# Organizadores de cocina Estanterías para cristalería
# Links encontrados... 35
# Tostadores y parrillas Aparatos para hacer pizza
# Links encontrados... 35
# Recipiente para comida Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Neveras
# Links encontrados... 35
# Molinillos para especias Cocina y comedor
# Links encontrados... 35
# Cestas y rejillas para barbacoas
# Links encontrados... 35
# Calentadores de comida Lámparas para calentar comida
# Links encontrados... 35
# Tenazas para alimentos Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Juegos para fondues
# Links encontrados... 35
# Herramientas y utensilios de cocina Espumaderas
# Links encontrados... 35
# Cestos para cocer al vapor Cocina y comedor
# Links encontrados... 35
# Accesorios para generadores de agua carbonatada Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Salseras
# Links encontrados... 35
# Electrodomésticos de cocina Tostadores y parrillas
# Links encontrados... 35
# Accesorios para microondas Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Deshidratadores de comida
# Links encontrados... 35
# Electrodomésticos de cocina Frigoríficos
# Links encontrados... 35
# Ollas de cocción lenta Cocina y comedor
# Links encontrados... 35
# Jarras y decantadores Cocina y comedor
# Links encontrados... 35
# Máquinas de pretzels Cocina y comedor
# Links encontrados... 35
# Filtros de agua para cafeteras Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Batidoras y licuadoras
# Links encontrados... 35
# Cocinas y zonas de cocina prefabricadas Cocina y comedor
# Links encontrados... 35
# Cortacápsulas Cocina y comedor
# Links encontrados... 35
# Prensadores de ajos Cocina y comedor
# Links encontrados... 35
# Accesorios para yogurteras Cocina y comedor
# Links encontrados... 35
# Granizadoras y picadoras de hielo
# Links encontrados... 35
# Utensilios de mesa Cafeteras y teteras
# Links encontrados... 35
# Cocinas y zonas de cocina prefabricadas
# Links encontrados... 35
# Accesorios para rodillos de cocina
# Links encontrados... 35
# Fundas para rodillos de cocina Cocina y comedor
# Links encontrados... 35
# Pinceles de cocina Cocina y comedor
# Links encontrados... 35
# Aislantes térmicos para latas y botellas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Sartenes para saltear
# Links encontrados... 35
# Anillos niveladores para rodillos de cocina Cocina y comedor
# Links encontrados... 35
# Vasijas para conservas y fermentación
# Links encontrados... 35
# Pellets y virutas de madera para ahumar Cocina y comedor
# Links encontrados... 35
# Termos dispensadores Cocina y comedor
# Links encontrados... 35
# Soportes para woks Cocina y comedor
# Links encontrados... 35
# Plantillas para comida y bebida Cocina y comedor
# Links encontrados... 35
# Fuentes para servir Cocina y comedor
# Links encontrados... 35
# Tapones Cocina y comedor
# Links encontrados... 35
# Tapaderas para sartenes y ollas
# Links encontrados... 35
# Accesorios para triturador de comida
# Links encontrados... 35
# Objetos para llevar comida y bebida Botellas de agua
# Links encontrados... 35
# Herramientas y utensilios de cocina Aplastadores de latas
# Links encontrados... 35
# WARNING:urllib3.connectionpool:Retrying (Retry(total=None, connect=2, read=2, redirect=2)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001434FD68>: Failed to establish a new connection: [Errno 10061] No connection could be made because the target machine actively refused it',))': http://google.es/search?safe=off&q=Cocina+y+comedor+Dispensadores+enfriadores+de+agua+Cocina+y+comedor&start=0&num=100&lr=lang_es&hl=es&gl=ES
# WARNING:urllib3.connectionpool:Retrying (Retry(total=None, connect=2, read=2, redirect=2)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001434FEB8>: Failed to establish a new connection: [Errno 10061] No connection could be made because the target machine actively refused it',))': http://google.es/search?safe=off&q=Cocina+y+comedor+Dispensadores+enfriadores+de+agua+Cocina+y+comedor&start=0&num=100&lr=lang_es&hl=es&gl=ES
# Dispensadores enfriadores de agua Cocina y comedor
# Links encontrados... 35
# Utensilios para hornear Bandejas para grill
# Links encontrados... 35
# Piezas de repuesto para barbacoas exteriores Cocina y comedor
# Links encontrados... 35
# Cafeteras Cafeteras con filtro
# Links encontrados... 35
# Accesorios para tostadoras Cocina y comedor
# Links encontrados... 35
# Aislantes térmicos para bebidas Aislantes térmicos para tazas
# Links encontrados... 35
# Soportes para tarta Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Dispensadores de bebidas
# Links encontrados... 35
# Palas de horno Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Teteras eléctricas
# Links encontrados... 35
# Cortadoras de fiambres Cocina y comedor
# Links encontrados... 35
# Cafeteras y teteras Cocina y comedor
# Links encontrados... 35
# Recipiente para comida Fiambreras
# Links encontrados... 35
# Hervidores eléctricos Cocina y comedor
# Links encontrados... 35
# Accesorios para deshidratadores de alimentos
# Links encontrados... 35
# Pesos y pinzas para manteles
# Links encontrados... 35
# Cesta para filtros del café Cocina y comedor
# Links encontrados... 35
# Accesorios para máquina de algodón dulce Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar y para hornear Cocina y comedor
# Links encontrados... 35
# Accesorios para hacer pasta Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Abrelatas
# Links encontrados... 35
# Frigoríficos Cocina y comedor
# Links encontrados... 35
# Cubiertos Cucharas
# Links encontrados... 35
# Utensilios de mesa Cubiertos
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para freidoras
# Links encontrados... 35
# Servilleteros y dispensadores de servilletas
# Links encontrados... 35
# Accesorios para hornear Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Cocina y comedor
# Links encontrados... 35
# Briquetas de carbón Cocina y comedor
# Links encontrados... 35
# Deshidratadores de comida Cocina y comedor
# Links encontrados... 35
# Sandwicheras Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Bandejas para tartas
# Links encontrados... 35
# Herramientas y utensilios de cocina Esterillas para sushi
# Links encontrados... 35
# Paños de amasar Cocina y comedor
# Links encontrados... 32
# Electrodomésticos de cocina Extractores
# Links encontrados... 35
# Electrodomésticos de cocina Preparadores de bebidas calientes
# Links encontrados... 35
# Plantillas para comida y bebida
# Links encontrados... 35
# Cestos para cocer al vapor
# Links encontrados... 35
# Cafeteras Cafeteras de émbolo
# Links encontrados... 35
# Cocteleras y accesorios Maza de mortero
# Links encontrados... 35
# Vajilla Juegos de vajilla
# Links encontrados... 35
# Paelleras Cocina y comedor
# Links encontrados... 35
# Accesorios para placas de cocción, hornos y cocinas de gas Cocina y comedor
# Links encontrados... 35
# Pistolas para cecinas Cocina y comedor
# Links encontrados... 35
# Apartadores Cocina y comedor
# Links encontrados... 35
# Cocteleras y accesorios Picadoras de hielo
# Links encontrados... 35
# Botes de galletas Cocina y comedor
# Links encontrados... 35
# Cubiertos Cocina y comedor
# Links encontrados... 35
# Tostadores y parrillas Sandwicheras
# Links encontrados... 35
# Soportes para poncheras Cocina y comedor
# Links encontrados... 35
# Bandejas Cocina y comedor
# Links encontrados... 35
# Accesorios para barbacoas Briquetas de carbón
# Links encontrados... 35
# Objetos para llevar comida y bebida Tapones de botellas
# Links encontrados... 35
# Calentadores de comida Vitrinas calientes
# Links encontrados... 35
# Herramientas y utensilios de cocina Palas de horno
# Links encontrados... 35
# Accesorios para máquinas de hielo
# Links encontrados... 35
# Accesorios para juegos de fondue Tenedores para fondue
# Links encontrados... 35
# Accesorios para campana de cocina Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Woks
# Links encontrados... 35
# Herramientas y utensilios de cocina Esteras antideslizantes para fregaderos
# Links encontrados... 35
# Ollas a presión Cocina y comedor
# Links encontrados... 35
# Tazas Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Prensadores de ajos
# Links encontrados... 35
# Accesorios de envasado al vacío
# Links encontrados... 35
# Herramientas y utensilios de cocina
# Links encontrados... 35
# Cocteleras y accesorios Gusanillos para colar cócteles
# Links encontrados... 35
# Bolsas de envasado al vacío Cocina y comedor
# Links encontrados... 35
# Ollas altas Cocina y comedor
# Links encontrados... 35
# Fiambreras Cocina y comedor
# Links encontrados... 35
# Accesorios para neveras de vinos Cocina y comedor
# Links encontrados... 35
# Espátulas de parrilla Cocina y comedor
# Links encontrados... 35
# Palilleros y dispensadores de palillos
# Links encontrados... 35
# Electrodomésticos de cocina Placas para calentar
# Links encontrados... 34
# Calentadores de comida Escalfadores
# Links encontrados... 35
# Picadoras de hielo Cocina y comedor
# Links encontrados... 35
# Cafeteras Cocina y comedor
# Links encontrados... 35
# Accesorios para cafeteras Filtros de café
# Links encontrados... 35
# Cubiertos Palillos
# Links encontrados... 35
# Vajilla Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas de hielo
# Links encontrados... 35
# Fuentes para soufflé y quesadillas
# Links encontrados... 35
# Dispensadores de film plástico Cocina y comedor
# Links encontrados... 35
# Cubiertos Cuchillos de mesa
# Links encontrados... 35
# Utensilios para hornear Piedras para pizza
# Links encontrados... 35
# Electrodomésticos de cocina Barbacoas
# Links encontrados... 35
# Máquinas de palomitas Cocina y comedor
# Links encontrados... 35
# Refrigeradores de bebidas Cocina y comedor
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para congeladores
# Links encontrados... 35
# Utensilios para hornear Bandejas para hornear galletas
# Links encontrados... 35
# Accesorios para barbacoas Chimeneas de carbón
# Links encontrados... 35
# Objetos para llevar comida y bebida
# Links encontrados... 35
# Moldes y sellos para pasta Cocina y comedor
# Links encontrados... 35
# Cafetera cona (por vacío) Cocina y comedor
# Links encontrados... 35
# Grifos y dispensadores de cerveza Cocina y comedor
# Links encontrados... 35
# Sartenes para freír Cocina y comedor
# Links encontrados... 35
# Contenedores para utensilios de cocina Cocina y comedor
# Links encontrados... 35
# Calentadores de comida Cocina y comedor
# Links encontrados... 35
# Accesorios para cortapizzas Cocina y comedor
# Links encontrados... 35
# Máquinas de hacer espuma de leche
# Links encontrados... 35
# Herramientas y utensilios de cocina Termómetros de cocina
# Links encontrados... 35
# Peladores y descorazonadores Cocina y comedor
# Links encontrados... 35
# Bandejas para deshidratadores de alimentos Cocina y comedor
# Links encontrados... 35
# Planchas de gas Cocina y comedor
# Links encontrados... 35
# Cocina y comedor Electrodomésticos de cocina
# Links encontrados... 35
# Pinzas para bolsas y ataduras de alambre Cocina y comedor
# Links encontrados... 35
# Moldes para tartas Cocina y comedor
# Links encontrados... 35
# Preparadores de bebidas calientes Cocina y comedor
# Links encontrados... 35
# Bolsas para horno Cocina y comedor
# Links encontrados... 35
# Platos de café y té Cocina y comedor
# Links encontrados... 35
# Accesorios para barbacoas Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas para derretir chocolate
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para hacer pasta
# Links encontrados... 35
# Aislantes térmicos para tazas Cocina y comedor
# Links encontrados... 35
# Ollas de vapor para alimentos Cocina y comedor
# Links encontrados... 35
# Vasos de chupito Cocina y comedor
# Links encontrados... 35
# Tijeras de cocina Cocina y comedor
# Links encontrados... 35
# Poncheras Cocina y comedor
# Links encontrados... 35
# Cortapastas extensibles con ruedas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar y para hornear Accesorios para hornear
# Links encontrados... 35
# Láminas para deshidratadores de alimentos Cocina y comedor
# Links encontrados... 35
# Objetos para llevar comida y bebida Termos
# Links encontrados... 35
# Tenazas para alimentos Pinzas para mariscos
# Links encontrados... 35
# Accesorios para el almacenamiento de comida Absorbentes de oxígeno
# Links encontrados... 35
# Termos Cocina y comedor
# Links encontrados... 35
# Bolsas de envasado al vacío
# Links encontrados... 35
# Soportes para botellas de vino Cocina y comedor
# Links encontrados... 35
# Accesorios para máquinas de palomitas Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Cortadoras de fiambres
# Links encontrados... 35
# Soportes para soperas Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Poncheras
# Links encontrados... 35
# Electrodomésticos de cocina Planchas y parrillas eléctricas
# Links encontrados... 35
# Cortadores de pizza Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Embudos
# Links encontrados... 35
# Portacuchillos y bloques para cuchillos
# Links encontrados... 35
# Organizadores de armarios de cocina Cocina y comedor
# Links encontrados... 35
# Jarras de café Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Tazas y cucharas medidoras
# Links encontrados... 35
# Palas para pasteles Cocina y comedor
# Links encontrados... 35
# Raspadores de cocina Espátulas de parrilla
# Links encontrados... 35
# Utensilios de servir Copas para huevos
# Links encontrados... 35
# Utensilios para cocinar Hervidores de agua
# Links encontrados... 35
# Tazas de café y té Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar y para hornear Accesorios para cocinar
# Links encontrados... 35
# Vasos y jarras de cerveza Cocina y comedor
# Links encontrados... 35
# Utensilios de mesa Vajilla
# Links encontrados... 35
# Cafeteras italianas tradicionales y eléctricas
# Links encontrados... 35
# Utensilios de mesa Cocina y comedor
# Links encontrados... 35
# Recipientes para azucarillos Cocina y comedor
# Links encontrados... 35
# Morteros Cocina y comedor
# Links encontrados... 35
# Juegos de vajilla Cocina y comedor
# Links encontrados... 35
# Calentadores para jarras de café
# Links encontrados... 35
# Utensilios para cocinar Sartenes para crepes
# Links encontrados... 35
# Fuentes para soufflé y quesadillas Cocina y comedor
# Links encontrados... 35
# Cascanueces decorativos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Soplete para cocinar
# Links encontrados... 35
# Envasados al vacío Cocina y comedor
# Links encontrados... 35
# Tazas y cucharas medidoras Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Rodillos de cocina
# Links encontrados... 35
# Accesorios para deshidratadores de alimentos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Escurridores de ensalada
# Links encontrados... 35
# Organizadores de cocina Organizadores de latas
# Links encontrados... 35
# Tapas de cubetas para mesas de vapor Cocina y comedor
# Links encontrados... 35
# Esterillas para sushi Cocina y comedor
# Links encontrados... 35
# Mangos para sartenes y ollas Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Máquinas de palomitas
# Links encontrados... 35
# Tapas para soperas Cocina y comedor
# Links encontrados... 35
# Accesorios para cafeteras Jarras para espumar
# Links encontrados... 35
# Hornos microondas Cocina y comedor
# Links encontrados... 35
# Posavasos Cocina y comedor
# Links encontrados... 35
# Accesorios para ollas a presión Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Trituradores de desechos
# Links encontrados... 35
# Accesorios para palillos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Organizadores de cocina
# Links encontrados... 35
# Pinchos y brochetas para comida
# Links encontrados... 35
# Cubiertas para barbacoas Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Escurreplatos
# Links encontrados... 35
# Tazas de café y té
# Links encontrados... 35
# Bolsas de cocción al vapor
# Links encontrados... 35
# Recipiente para comida Cubos de caramelos
# Links encontrados... 35
# Cámaras 4
# Cámaras Boroscopios
# Links encontrados... 35
# Cámaras Cámaras de fotos desechables
# Links encontrados... 35
# Cámaras Cámaras trampa
# Links encontrados... 35
# Cámaras de vídeo Cámaras
# Links encontrados... 35
# Cámaras Cámaras de cine
# Links encontrados... 35
# Boroscopios Cámaras
# Links encontrados... 35
# Cámaras web Cámaras
# Links encontrados... 35
# Cámaras Cámaras web
# Links encontrados... 35
# Cámaras de fotos desechables Cámaras
# Links encontrados... 35
# Cámaras Cámaras de vídeo
# Links encontrados... 35
# Cámaras Cámaras digitales
# Links encontrados... 35
# Cámaras Cámaras de vigilancia
# Links encontrados... 35
# Cámaras trampa Cámaras
# Links encontrados... 35
# Cámaras de vigilancia Cámaras
# Links encontrados... 35
# Cámaras de cine Cámaras
# Links encontrados... 35
# Cámaras digitales Cámaras
# Links encontrados... 35
# GOOGLE TERMINADO -- PASAMOS A LOS DOCUMENTOS

# %% [markdown]
# ### Download web pages

# %%
seoLibraries = {}

for topic, topicQueries in search_topics.items():
    seoDocuments = []
    num_download = min(len(topicQueries), 20)
    
    print("%s %s"%(topic, num_download))
    for topicQuery in topicQueries:
        print(topicQuery)
        _getGoogleLinks(translator.trans(topic + u' ' + topicQuery), language, country, TRAINER_DOWNLOAD_LIMIT)      
        seoDocuments.extend(_getSeoDocuments(translator.trans(topic + u' ' + topicQuery), language, country, TRAINER_DOWNLOAD_LIMIT))

        
    if len(seoDocuments) > 10:
        seoLibraries[topic] = SeoLibrary(topic, language, country)
        seoLibraries[topic].seoDocuments = seoDocuments        
        
print (u'DOCUMENTOS DESCARGADOS')
# Out:
# Mantenimiento del orden público 4
# Mantenimiento del orden público Sujeciones mecánicas
# Links encontrados... 35
# Detectores de metal Mantenimiento del orden público
# Links encontrados... 35
# Sujeciones mecánicas Mantenimiento del orden público
# Links encontrados... 35
# Mantenimiento del orden público Detectores de metal
# Links encontrados... 35
# Cocina y comedor 20
# Filtros de agua para cafeteras
# Links encontrados... 35
# Cuencos Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Fuentes para servir
# Links encontrados... 35
# Rodillos de cocina Cocina y comedor
# Links encontrados... 35
# Cucharas Cocina y comedor
# Links encontrados... 35
# Recipientes para arroz Cocina y comedor
# Links encontrados... 35
# Cuencos de heladeras para frigorífico Cocina y comedor
# Links encontrados... 35
# Rejillas para barbacoas Cocina y comedor
# Links encontrados... 35
# Juegos de cristalería Cocina y comedor
# Links encontrados... 35
# Accesorios para termómetros de cocina
# Links encontrados... 35
# Envoltorios de comida Papel de cera
# Links encontrados... 35
# Palilleros y dispensadores de palillos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Raspadores de cocina
# Links encontrados... 35
# Cepillos de woks Cocina y comedor
# Links encontrados... 35
# Electrodomésticos de cocina Neveras para vino
# Links encontrados... 35
# Soperas Cocina y comedor
# Links encontrados... 35
# Ollas de hierro Cocina y comedor
# Links encontrados... 35
# Accesorios para el almacenamiento de comida Cocina y comedor
# Links encontrados... 35
# Cantimploras Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Trituradores
# Links encontrados... 35
# Accesorios para aparatos de cocina Accesorios para fogones portátiles
# Links encontrados... 35
# Hornillas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Cacillos
# Links encontrados... 35
# Utensilios de servir Soperas
# Links encontrados... 35
# Electrodomésticos de cocina Yogurteras
# Links encontrados... 35
# Frascos Cocina y comedor
# Links encontrados... 35
# Tapaderas para sartenes y ollas Cocina y comedor
# Links encontrados... 35
# Moldes para quiche y tarta Cocina y comedor
# Links encontrados... 35
# Envoltorios de comida Papel de aluminio
# Links encontrados... 35
# Pesos y pinzas para manteles Cocina y comedor
# Links encontrados... 35
# Dispensadores de comida Cocina y comedor
# Links encontrados... 35
# Utensilios para bares Tapones para botellas
# Links encontrados... 35
# Juegos de café y té
# Links encontrados... 35
# Herramientas y utensilios de cocina Cronómetros de cocina
# Links encontrados... 35
# Cocteleras y accesorios Cocteleras
# Links encontrados... 35
# Cuencos de heladeras para frigorífico
# Links encontrados... 35
# Etiquetas para alimentos y bebidas Cocina y comedor
# Links encontrados... 35
# Juegos de utensilios para hornear
# Links encontrados... 35
# Copas Cocina y comedor
# Links encontrados... 35
# Dispensadores de condimentos Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Tenazas para alimentos
# Links encontrados... 35
# Herramientas y utensilios de cocina Ablandadores de carne
# Links encontrados... 35
# Pinzas de cocina Cocina y comedor
# Links encontrados... 35
# Hornos Cocina y comedor
# Links encontrados... 35
# Accesorios de sartenes para gofres
# Links encontrados... 35
# Especieros Cocina y comedor
# Links encontrados... 35
# Carros para barbacoas Cocina y comedor
# Links encontrados... 35
# Utensilios para cocinar Sartenes para freír
# Links encontrados... 34
# Utensilios de servir Platos para mantequilla
# Links encontrados... 35
# Herramientas y utensilios de cocina Cuchillos de cocina
# Links encontrados... 35
# Raspadores de cocina Rasquetas
# Links encontrados... 35
# Herramientas y utensilios de cocina Bandejas cubiteras
# Links encontrados... 35
# Apartadores y guantes para horno Cocina y comedor
# Links encontrados... 35
# Utensilios de servir Jarras y decantadores
# Links encontrados... 35
# Tapas para tuppers Cocina y comedor
# Links encontrados... 35
# Herramientas y utensilios de cocina Cucharas para bolas
# Links encontrados... 35
# Cafeteras con filtro Cocina y comedor
# Links encontrados... 35
# Freidoras Cocina y comedor
# Links encontrados... 35
# Arroceras Cocina y comedor
# Links encontrados... 35
# Ollas de vapor para alimentos Ollas de vapor
# Links encontrados... 35
# Electrodomésticos de cocina Heladeras
# Links encontrados... 35
# Tapones para botellas Cocina y comedor
# Links encontrados... 35
# Salseras Cocina y comedor
# Links encontrados... 35
# Accesorios para rodillos de cocina Cocina y comedor
# Links encontrados... 35
# Azucareros y lecheras Cocina y comedor

# %%
#Juntamos datos

targetList = []
documentList = []
for topic, seoLibrary in seoLibraries.items():
    print u'Topic: %s Documents Downloaded: %s' % (seoLibrary.query, len(seoLibrary.seoDocuments))
    for seoDocument in seoLibrary.seoDocuments:
        try:
            documentList.append(u' '.join(seoDocument.getTextTokens(lemmatize=True)))
            targetList.append(topic)
        except Exception as ex:
            print(ex)

# %%
from ete3 import Tree

# %% [markdown]
# ### Clasificador

# %%
classif = OneVsRestClassifier(LinearSVC(tol=0.1, dual=True, penalty='l2'))
